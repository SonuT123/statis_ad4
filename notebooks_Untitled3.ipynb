# %% [markdown]
#                                                 Assignment statistics advance - 4

# %% [markdown]
# Q1: What is the difference between a t-test and a z-test? Provide an example scenario where you would
#     use each type of test.

# %% [raw]
# A t-test and a z-test are both statistical hypothesis tests used to make inferences about population parameters based on sample data
#
# 1.T-test:-
#          Use Case: T-tests are used when you want to compare the means of two groups (independent samples) or when you want
#           to compare a sample mean to a known population mean when the population standard deviation is unknown.
#
#           Example Scenario: Suppose you want to test whether there is a significant difference in the average test
#                   scores between two groups of students, Group A and Group B. You collect sample data from both
#                   groups and use a t-test to determine if the difference in means is statistically significant.
#
#
#
# Z-test:
#        Use Case: Z-tests are used when you want to compare a sample mean to a known population mean, and you have a large
#         sample size (typically n > 30) or when you know the population standard deviation.
#
#
#        Example Scenario: Let's say you are conducting a survey to determine if the average height of a sample of adults in your
#                 city is significantly different from the known average height of adults in the entire country.
#                 If you have a large enough sample size (e.g., more than 30), and you know the population standard deviation,
#                  you can use a z-test to make this comparison.
#
#
#
# key differences between t-tests and z-tests:-
#
#     Sample Size: T-tests are more suitable for small sample sizes (typically n < 30), while z-tests are appropriate
#                             for larger sample sizes (typically n > 30).
#
#
#     Standard Deviation: T-tests do not require knowledge of the population standard deviation, whereas z-tests
#                  assume that you know the population standard deviation or have a large sample size where the sample
#                  standard deviation can be a good approximation.
#
#     Independence: T-tests are used when comparing two independent groups, while z-tests are often used for comparing
#                 a sample to a known population value.

# %% [markdown]
# Q2: Differentiate between one-tailed and two-tailed tests.

# %% [raw]
# One-tailed tests and two-tailed tests are two different types of hypothesis tests used in statistics.
# They differ in terms of the directionality of the test and the hypotheses being tested:
#
# 1.One-Tailed Test:-
#                   Directionality: In a one-tailed test, you are interested in testing
#                   a hypothesis in only one direction, either in the "greater than" (right-tailed)
#                   direction or the "less than" (left-tailed) direction.
#
#     Hypotheses:-
#             >Null Hypothesis (H0): This hypothesis typically represents the status quo or no effect.
#                 In a one-tailed test, it states that there is no effect or difference in a specific direction.
#
#              >Alternative Hypothesis (Ha): The alternative hypothesis in a one-tailed test specifies a particular
#                 direction of effect or difference.
#
#      Example:-
#             Suppose you are testing whether a new drug increases the average survival time of patients.
#             Your hypotheses might be:
#
#
#             H0: The new drug has no effect on survival time (average survival time is the same or less).
#             Ha: The new drug increases survival time (average survival time is greater).
#
#     Critical Region: In a one-tailed test, the critical region (the area of the distribution that leads to rejection
#            of the null hypothesis) is concentrated in one tail of the distribution, either on the right or left side,
#            depending on the direction of the test.
#
#  2.Two-Tailed Test:-
#                   >Directionality: In a two-tailed test, you are interested in testing a hypothesis in both directions,
#                    both "greater than" and "less than" the expected value or null hypothesis value.
#         >Hypotheses:-
#                    >Null Hypothesis (H0):-This hypothesis typically represents the status quo or no effect.
#                     In a two-tailed test, it states that there is no effect or difference, regardless of direction.
#
#                    >Alternative Hypothesis (Ha): The alternative hypothesis in a two-tailed test is more general
#                        and states that there is a difference or effect, but it does not specify the direction.
#              Example:-
#
#                      Let's say you are testing whether a coin is fair (i.e., it has an equal probability of landing
#                            heads or tails). Your hypotheses might be:
#
#
#                     >H0: The coin is fair (the probability of heads is 0.5).
#                     >Ha: The coin is not fair (the probability of heads is not equal to 0.5).
#
#                  >Critical Region: In a two-tailed test, the critical region is divided into two parts,
#                     one in each tail of the distribution. This allows for testing differences in both directions
#                     from the null hypothesis value.

# %% [markdown]
# Q3: Explain the concept of Type 1 and Type 2 errors in hypothesis testing. Provide an example scenario for
# each type of error.

# %% [raw]
# In hypothesis testing, Type I and Type II errors are two types of errors that can occur when making
#    decisions about the null hypothesis. These errors are associated with the correctness of the decisions
#     made based on the statistical tests.
#
# 1.Type I Error (False Positive):-
#   >Definition:-A Type I error occurs when you incorrectly reject the null hypothesis when it is actually true.
#     In other words, you conclude that there is a significant effect or difference when there isn't one in reality.
#
#   >Symbol:-Often denoted as α (alpha), it represents the significance level or the probability of making a Type I error.
#
# Example Scenario:-
#
#       >Suppose a pharmaceutical company is testing a new drug for a rare disease. The null hypothesis (H0) states that
#         the drug has no effect, while the alternative hypothesis (Ha) claims that the drug is effective.
#         If the researchers conduct a clinical trial and, based on the data, incorrectly conclude that the
#         drug is effective (rejecting H0) when, in fact, it is not, they have committed a Type I error.
#         This could lead to the drug being approved when it should not have been.
#
# 2.Type II Error (False Negative):-
#      >Definition: A Type II error occurs when you fail to reject the null hypothesis when it is actually false.
#      In other words, you conclude that there is no significant effect or difference when there is one in reality.
#
#     >Symbol: Often denoted as β (beta), it represents the probability of making a Type II error.
#
#     >Example Scenario:-
#
#      >Consider a quality control scenario in a manufacturing plant. The null hypothesis (H0) states that the
#         production process is within acceptable quality limits, while the alternative hypothesis (Ha) claims
#         that the process is producing defective items. If the plant conducts a quality test and, based on the data,
#         fails to identify a significant problem (fails to reject H0) when, in fact, the process is producing defects,
#         they have committed a Type II error. This could result in a batch of defective products reaching customers.
#
#
# >Type I Error is associated with the risk of wrongly concluding that there is an effect or difference when there isn't (false positive)
# >Type II Error is associated with the risk of wrongly concluding that there is no effect or difference when there actually is one (false negative).
#
#
# The balance between Type I and Type II errors can often be adjusted by choosing an appropriate significance level (α) and by increasing the sample
#     size in hypothesis testing. However, there is typically a trade-off between the two types of errors: reducing the risk of one type of error
#     often increases the risk of the other. Researchers must carefully consider the consequences of these errors when designing and interpreting
#     hypothesis tests to make informed decisions.

# %% [markdown]
# Q4: Explain Bayes's theorem with an example.

# %% [raw]
# Bayes' theorem is a fundamental concept in probability theory and statistics that describes how to update
# the probability of a hypothesis (or event) based on new evidence. It provides a way to incorporate prior
# knowledge and new data to make more informed probabilistic decisions. The theorem is named after the Reverend
# Thomas Bayes, an 18th-century statistician and theologian.
#
# Bayes' theorem :-
#                P(A|B) = P(B|A) * P(A) / P(B)
#
#
# Where:-
#
#     >P(A|B) is the probability of event A occurring given that event B has already occurred (posterior probability)
#     >P(B|A) is the probability of event B occurring given that event A has already occurred (likelihood)
#     >P(A) is the probability of event A occurring without any prior knowledge of event B (prior probability)
#     >P(B) is the probability of event B occurring without any prior knowledge of event A
#
# example of how to use Bayes' theorem:
#
# Suppose you are playing a game where you have to draw a ball from a bag. The bag contains 5 red balls and 5 blue balls.
# You draw a ball and it is red. What is the probability that the bag contains more red balls than blue balls?
#
# We can use Bayes' theorem to answer this question.
#
# Let:
#     A = the event that the bag contains more red balls than blue balls
#     B = the event that you draw a red ball
#
# We know
#
#     P(B|A) = 1, because if the bag contains more red balls than blue balls, then the probability of drawing a red ball is 1.
#     P(A) = 1/2, because there is a 50% chance that the bag contains more red balls than blue balls.
#     P(B) = 1/2, because there is a 50% chance of drawing a red ball from the bag.
#
#
# We want to find P(A|B), which is the probability that the bag contains more red balls than blue balls given that you drew a red ball.
#
# Using Bayes' theorem:
#
#     P(A|B) = P(B|A) * P(A) / P(B)
#     P(A|B) = 1 * 1/2 / 1/2
#     P(A|B) = 1
#
#
# Therefore, the probability that the bag contains more red balls than blue balls given that you drew a red ball is 1.
#
# >Diagnose diseases
# >Classify documents
# >Filter spam emails
# >Recommend products to customers
# >Predict the weather

# %% [raw]
# Q5: What is a confidence interval? How to calculate the confidence interval, explain with an example.

# %% [raw]
# A confidence interval is a range of values that is likely to contain the true population parameter of interest.
#     It is calculated using a sample statistic and a margin of error. The margin of error is a measure of how much
#     the sample statistic is likely to vary from the true population parameter.
#
#  calculate a confidence interval
#
#    * The sample statistic
#    * The standard deviation of the sample
#    * The sample size
#    * The desired confidence level
#
# The confidence level is the probability that the confidence interval will contain the true population parameter.
#    The most common confidence levels are 90%, 95%, and 99%.
#
#  formula
#    Confidence interval = sample statistic ± margin of error
#
#
#    The margin of error is calculated using the following formula:
#
#
#     Margin of error = critical value * standard deviation of the sample / √sample size
#
#
# The critical value is a value that is determined by the desired confidence level and the number
#     of degrees of freedom in the sample. The number of degrees of freedom in the sample is equal to the sample size minus 1.
#
#  example of how to calculate a confidence interval:
#
# Suppose you are interested in estimating the average height of all adults in the United States.
#    You take a random sample of 100 adults and find that the average height in the sample is 68 inches.
#     The standard deviation of the sample is 3 inches.
#
# To calculate a 95% confidence interval for the average height of all adults in the United States,
#
#
#     1. Find the critical value for a 95% confidence level and 99 degrees of freedom (100 - 1). The critical value is 1.984.
#     2. Calculate the margin of error:
#
#
#     Margin of error = 1.984 * 3 inches / √100
#
#
#
#     Margin of error = 0.97 inches
#
#     3. Calculate the confidence interval:
#
#
#     Confidence interval = 68 inches ± 0.97 inches
#
#
#       Confidence interval = 67.03 inches to 68.97 inches
#
#
#    Therefore, we can be 95% confident that the true average height of all adults in the United States is between 67.03 inches and 68.97 inches.
#
#   Confidence intervals are a useful tool for estimating population parameters and for assessing the uncertainty of our estimates.
#   They are used in a wide variety of fields, including statistics, medicine, engineering, and economics.

# %% [markdown]
# Q6. Use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge of the
#     event's probability and new evidence. Provide a sample problem and solution.

# %% [raw]
# To use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge
#              of the event's probability and new evidence,
#
#
#
#      P(A|B) = P(B|A) * P(A) / P(B)
#
#
#     where:
#
#      P(A|B) is the probability of event A occurring given that event B has already occurred (posterior probability)
#      P(B|A) is the probability of event B occurring given that event A has already occurred (likelihood)
#      P(A) is the probability of event A occurring without any prior knowledge of event B (prior probability)
#      P(B) is the probability of event B occurring without any prior knowledge of event A
#
#     **Sample problem:**
#
#     Suppose you are playing a game where you have to draw a ball from a bag. The bag contains 5 red balls and 5 blue balls. You draw a ball and it           is red. What is the probability that the bag contains more red balls than blue balls?
#
#      **Solution:**
#
#    Let:
#
#       A = the event that the bag contains more red balls than blue balls
#      B = the event that you draw a red ball
#
#    We know the following:
#
#     P(B|A) = 1, because if the bag contains more red balls than blue balls, then the probability of drawing a red ball is 1.
#     P(A) = 1/2, because there is a 50% chance that the bag contains more red balls than blue balls.
#
#   To calculate P(B), we can use the following formula:
#
#
#    P(B) = P(B|A) * P(A) + P(B|¬A) * P(¬A)
#
#
#    where:
#
#    P(B|¬A) is the probability of drawing a red ball given that the bag does not contain more
#     red balls than blue balls (the complement of event A)
#    P(¬A) is the probability that the bag does not contain more red balls than blue balls
#
#    P(B|¬A) is the probability of drawing a red ball from a bag that contains 5 red balls
#    and 5 blue balls. This probability is equal to 1/2.
#
#   P(¬A) is the probability that the bag does not contain more red balls than blue balls.
#      This probability is also equal to 1/2.
#
#   Therefore, we can calculate P(B) as follows:
#
#
#    P(B) = 1 * 1/2 + 1/2 * 1/2
#
#
#
#      P(B) = 3/4
#
#
#    Now, we can calculate P(A|B) as follows:
#
#
#     P(A|B) = P(B|A) * P(A) / P(B)
#
#
#
#     P(A|B) = 1 * 1/2 / 3/4
#
#
#
#     P(A|B) = 2/3
#
#
#  Therefore, the probability that the bag contains more red balls than blue balls
#   given that you drew a red ball is 2/3.
#
# Bayes' Theorem can be used to solve a wide variety of problems.
# It is based on the idea that we can update our beliefs about the world as we learn new information.

# %% [raw]
# Q7. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
#     of 5. Interpret the results.

# %% [raw]
# To calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5,
#     we can use the following formula:
#
#
#      Confidence interval = sample statistic ± margin of error
#
#
#      The margin of error is calculated using the following formula:
#
#
#      argin of error = critical value * standard deviation of the sample / √sample size
#
#
#       The critical value for a 95% confidence interval and a sample size of at least 30 is 1.96.
#
#      Therefore, the margin of error is calculated as follows:
#
#         Margin of error = 1.96 * 5 / √30
#
#         Margin of error = 1.67
#
#
#        The confidence interval is then calculated as follows:
#
#
#        Confidence interval = 50 ± 1.67
#
#
#        Confidence interval = 48.33 to 51.67
#
#
#         Therefore, we can be 95% confident that the true population mean is between 48.33 and 51.67.
#
#      Interpretation of the results:
#
#    The 95% confidence interval tells us that we are 95% confident that the true population mean is between 48.33 and 51.67.
#         This means that if we were to repeat this study many times and calculate the 95% confidence interval each time
#         95% of the time the interval would contain the true population mean
#         Another way to interpret the confidence interval is to say that we are 95% confident that the true population mean is
#         within 1.67 units of the sample mean of 50.
#
#    Confidence intervals are a useful tool for estimating population parameters and for assessing the uncertainty of our estimates.
#         They are used in a wide variety of fields, including statistics, medicine, engineering, and economics.

# %% [markdown]
# Q8. What is the margin of error in a confidence interval? How does sample size affect the margin of error?
#      Provide an example of a scenario where a larger sample size would result in a smaller margin of error.

# %% [raw]
# The margin of error in a confidence interval is a measure of how much the sample statistic is likely
#           to vary from the true population parameter.
#
#
#         Margin of error = critical value * standard deviation of the sample / √sample size
#
#
#       he critical value is a value that is determined by the desired confidence level and the number of degrees
#         of freedom in the sample. The number of degrees of freedom in the sample is equal to the sample size minus 1.
#
#     How sample size affects margin of error:
#
#       The sample size has a direct impact on the margin of error. The larger the sample size,
#         the smaller the margin of error. This is because a larger sample size provides more information about the population,
#         and therefore allows us to make more accurate estimates of the population parameters.
#
#     Example scenario:
#
#      Suppose we are interested in estimating the average height of all adults in the United States.
#      We take a random sample of 100 adults and find that the average height in the sample is 68 inches.
#         The standard deviation of the sample is 3 inches.
#
#     To calculate the 95% confidence interval for the average height of all adults in the United States,
#       we would use the following steps:
#
#         1. Find the critical value for a 95% confidence level and 99 degrees of freedom (100 - 1). The critical value is 1.984.
#         2. Calculate the margin of error:
#
#
#       margin of error = 1.984 * 3 inches / √100
#
#
#
#       Margin of error = 0.97 inches
#
#
#     5. Calculate the confidence interval:
#
#
#       Confidence interval = 68 inches ± 0.97 inches
#
#
#
#        Confidence interval = 67.03 inches to 68.97 inches
#
#
#      Therefore, we can be 95% confident that the true average height of all adults in the United States
#                is between 67.03 inches and 68.97 inches.
#
#      Now, suppose we take a random sample of 1000 adults instead of 100 adults.
#           The standard deviation of the sample is still 3 inches.
#
#       To calculate the 95% confidence interval for the average height of all adults in the United States,
#           we would use the following steps:
#
#           1. Find the critical value for a 95% confidence level and 999 degrees of freedom (1000 - 1). The critical value is 1.96.
#           2. Calculate the margin of error:
#
#
#            Margin of error = 1.96 * 3 inches / √1000
#
#
#
#            Margin of error = 0.3 inches
#
#
#           3. Calculate the confidence interval:
#
#
#              Confidence interval = 68 inches ± 0.3 inches
#
#
#
#             Confidence interval = 67.7 inches to 68.3 inches
#
#
#           Therefore, we can be 95% confident that the true average height of all adults in the United
#                     States is between 67.7 inches and 68.3 inches.
#
#         As you can see, the margin of error in the confidence interval is smaller when the sample size is larger.
#            This is because a larger sample size provides more information about the population,
#             and therefore allows us to make more accurate estimates of the population parameters.
#
#        In general, it is always a good idea to use as large of a sample size as possible when conducting research.
#            This will help to ensure that your results are accurate and reliable.

# %% [markdown]
# Q9. Calculate the z-score for a data point with a value of 75, a population mean of 70, and a population
#      standard deviation of 5. Interpret the results.

# %% [raw]
# To calculate the z-score for a data point with a value of 75, a population mean of 70,
#        and a population standard deviation of 5
#
#
#        z-score = (x - μ) / σ
#
#
#       where:
#
#       x is the value of the data point
#       μ is the population mean
#       σ is the population standard deviation
#
#        Therefore, the z-score for the data point is:
#
#
#             z-score = (75 - 70) / 5
#
#
#
#             z-score = 1
#
#
#     A z-score of 1 means that the data point is 1 standard deviation above the population mean.
#       This means that the data point is more extreme than 68% of the data points in the population.
#
#       In other words, the data point is relatively high compared to the rest of the population.
#
#      Interpretation of the results:
#
#          The z-score can be used to interpret the significance of the data point.
#           A high z-score indicates that the data point is unlikely to have occurred by chance,
#           and is therefore more likely to be significant.
#
#          A low z-score, on the other hand, indicates that the data point is more likely to have occurred by chance,
#             and is therefore less likely to be significant.
#
#           In this case, the z-score of 1 indicates that the data point is relatively high compared to the rest of the population,
#                and is therefore more likely to be significant.
#
#              However, it is important to note that statistical significance does not necessarily mean practical significance.
#                 A statistically significant result may be too small to have any practical meaning.
#
#           To determine the practical significance of the result, we would need to consider the context of
#                the study and the size of the effect.

# %% [markdown]
# Q10. In a study of the effectiveness of a new weight loss drug, a sample of 50 participants lost an average
#       of 6 pounds with a standard deviation of 2.5 pounds. Conduct a hypothesis test to determine if the drug is
#       significantly effective at a 95% confidence level using a t-test.

# %% [raw]
# To conduct a hypothesis test to determine if the new weight loss drug is significantly effective at a 95% confidence
#       level using a t-test
#
#        1. State the null and alternative hypotheses.
#
#       The null hypothesis is that the drug is not effective at reducing weight, and the alternative hypothesis
#         is that the drug is effective at reducing weight.
#
#       2. Choose the appropriate test statistic.
#
#        Since we are comparing the mean weight loss in the sample to a known value (0),
#         we can use a one-sample t-test.
#
#       3. Calculate the test statistic.
#
#       The test statistic is calculated:
#
#
#        t = (sample mean - population mean) / (standard error of the mean)
#
#
#        The standard error of the mean is calculated as follows:
#
#
#         standard error of the mean = standard deviation / √sample size
#
#
#         In this case, the test statistic is calculated as follows:
#
#
#        t = (6 pounds - 0 pounds) / (2.5 pounds / √50)
#
#
#
#         t = 12
#
#
#       4. Determine the critical value.
#
#     The critical value is determined by the significance level and the degrees of freedom.
#      In this case, the significance level is 0.05 and the degrees of freedom are 49 (sample size - 1).
#
#     Using a t-table, we can find that the critical value for a one-tail test with a significance level of 0.05
#        and 49 degrees of freedom is 1.675.
#
#      5. Make a decision.
#
#       Since the test statistic (12) is greater than the critical value (1.675), we reject the null hypothesis
#         and conclude that the drug is significantly effective at reducing weight at a 95% confidence level.
#
#         Interpretation of the results:
#
#      The results of the hypothesis test indicate that the new weight loss drug is significantly effective
#        at reducing weight at a 95% confidence level. This means that we can be 95% confident that the true
#         average weight loss in the population is greater than 0 pounds.
#
#        However, it is important to note that statistical significance does not necessarily mean practical significance.
#         A statistically significant result may be too small to have any practical meaning.
#
#        To determine the practical significance of the result, we would need to consider the clinical significance
#              of the weight loss. For example, a weight loss of 6 pounds may be clinically significant for some patients,
#            but not for others.

# %% [markdown]
# Q11. In a survey of 500 people, 65% reported being satisfied with their current job. Calculate the 95%
#       confidence interval for the true proportion of people who are satisfied with their job.

# %% [raw]
# To calculate the 95% confidence interval for the true proportion of people who are satisfied with their
#          job in a survey of 500 people where 65% reported being satisfied with their current job,
#
#
#        Confidence interval = sample proportion ± margin of error
#
#
#       The margin of error is calculated using the following formula:
#
#
#         Margin of error = critical value * √(proportion * (1 - proportion)) / √sample size
#
#
#         The critical value for a 95% confidence level is 1.96.
#
#        Therefore, the margin of error is calculated as follows:
#
#
#          Margin of error = 1.96 * √(0.65 * 0.35) / √500
#
#
#
#         Margin of error = 0.03
#
#
#        The confidence interval is then calculated as follows:
#
#
#          Confidence interval = 0.65 ± 0.03
#
#
#
#         Confidence interval = (0.62, 0.68)
#
#
#         Therefore, we can be 95% confident that the true proportion of people who are satisfied with their job is between 62% and 68%.
#
#       Interpretation of the results:
#
#          The 95% confidence interval tells us that we are 95% confident that the true proportion of
#            eople who are satisfied with their job is between 62% and 68%. This means that if we were
#             to repeat this survey many times and calculate the 95% confidence interval each time, 95% of
#             the time the interval would contain the true population proportion.
#
#        Another way to interpret the confidence interval is to say that we are 95% confident that the true population
#             proportion is within 3 percentage points of the sample proportion of 65%.

# %% [markdown]
# Q12. A researcher is testing the effectiveness of two different teaching methods on student performance.
#       Sample A has a mean score of 85 with a standard deviation of 6, while sample B has a mean score of 82
#       significant difference in student performance using a t-test with a significance level of 0.01.

# %% [raw]
# To conduct a hypothesis test to determine if the two teaching methods have a significant difference
#     in student performance using a t-test with a significance level of 0.01
#
#      1. State the null and alternative hypotheses.
#
#      The null hypothesis is that there is no difference in student performance between the two teaching methods.
#       The alternative hypothesis is that there is a difference in student performance between the two teaching methods.
#
#      2. Choose the appropriate test statistic.
#
#         Since we are comparing the means of two independent samples,
#           we can use an independent samples t-test.
#
#      3. Calculate the test statistic.
#
#      the test statistic is calculated :
#
#
#       t = (sample mean A - sample mean B) / (standard error of the difference)
#
#
#         The standard error of the difference is calculated :
#
#
#        tandard error of the difference
#           = √((standard deviation of sample A)^2 / sample size of sample A + (standard deviation of sample B)^2 / sample size of sample B)
#
#
#      In this case, the test statistic is calculated
#
#          t = (85 - 82) / √((6^2 / 50) + (5^2 / 50))
#
#
#
#             t = 1.5
#
#
#         4. Determine the critical value.
#
#     The critical value is determined by the significance level and the degrees of freedom.
#     In this case, the significance level is 0.01 and the degrees of freedom are 98 (sample size of sample A + sample size of sample B - 2).
#
#        Using a t-table, we can find that the critical value for a two-tail test with a significance
#         level of 0.01 and 98 degrees of freedom is 2.626.
#
#         5. Make a decision.
#
#       Since the test statistic (1.5) is less than the critical value (2.626), we fail to reject the null hypothesis.
#             Therefore, we conclude that there is not enough evidence to support the claim that the two teaching methods
#              have a significant difference in student performance at a significance level of 0.01.
#
#        Interpretation of the results:
#
#        The results of the hypothesis test indicate that there is not enough evidence to support the claim
#         that the two teaching methods have a significant difference in student performance at a significance
#         level of 0.01. This means that we cannot conclude that one teaching method is better than the other.
#
#        However, it is important to note that this does not necessarily mean that there is no difference between
#          the two teaching methods. It is possible that a larger sample size would be needed to detect a statistically
#          significant difference.
#
#       To make a more definitive conclusion about the two teaching methods,
#        the researcher could conduct a follow-up study with a larger sample size.

# %% [markdown]
# Q13. A population has a mean of 60 and a standard deviation of 8. A sample of 50 observations has a mean
#      of 65. Calculate the 90% confidence interval for the true population mean.

# %% [raw]
# To calculate the 90% confidence interval for the true population mean in a population with a mean of 60
#     and a standard deviation of 8, and a sample of 50 observations with a mean of 65
#
#
#         Confidence interval = sample mean ± margin of error
#
#
#         The margin of error is calculated using
#
#
#         Margin of error = critical value * standard deviation of the sample / √sample size
#
#
#         The critical value for a 90% confidence level and 49 degrees of freedom (sample size - 1) is 1.675.
#
#         Therefore, the margin of error is calculated as follows:
#
#
#            Margin of error = 1.675 * 8 / √50
#
#
#
#            Margin of error = 2.56
#
#
#         The confidence interval is then calculated
#
#
#          Confidence interval = 65 ± 2.56
#
#
#
#           Confidence interval = (62.44, 67.56)
#
#
#          Therefore, we can be 90% confident that the true population mean is between 62.44 and 67.56.
#
#         Interpretation of the results:
#
#    The 90% confidence interval tells us that we are 90% confident that the true population mean
#       is between 62.44 and 67.56. This means that if we were to repeat this study many times and calculate
#       the 90% confidence interval each time, 90% of the time the interval would contain the true population mean.
#
#      Another way to interpret the confidence interval is to say that we are 90% confident that the true population
#         mean is within 2.56 units of the sample mean of 65.

# %% [markdown]
# Q14. In a study of the effects of caffeine on reaction time, a sample of 30 participants had an average
#       reaction time of 0.25 seconds with a standard deviation of 0.05 seconds. Conduct a hypothesis test to
#       determine if the caffeine has a significant effect on reaction time at a 90% confidence level using a t-test.

# %% [raw]
# To conduct a hypothesis test to determine if caffeine has a significant effect on reaction time at a 90%
#      confidence level using a t-test
#
#         1. State the null and alternative hypotheses.
#
#      The null hypothesis is that caffeine has no effect on reaction time.
#         The alternative hypothesis is that caffeine has an effect on reaction time.
#
#         2. Choose the appropriate test statistic.
#
#      Since we are comparing the mean reaction time in the sample to a known value (0 seconds), we can use a one-sample t-test.
#
#         3. Calculate the test statistic.
#
#       The test statistic is calculated
#
#
#           t = (sample mean - population mean) / (standard error of the mean)
#
#
#            The standard error of the mean is calculated as follows:
#
#
#            standard error of the mean = standard deviation / √sample size
#
#
#            In this case, the test statistic is calculated as follows:
#
#
#            t = (0.25 seconds - 0 seconds) / (0.05 seconds / √30)
#
#
#
#             t = 8.66
#
#
#          4. Determine the critical value.
#
#        The critical value is determined by the significance level and the degrees of freedom.
#         In this case, the significance level is 0.1 and the degrees of freedom are 29 (sample size - 1).
#
#       Using a t-table, we can find that the critical value for a one-tail test with a significance level
#           of 0.1 and 29 degrees of freedom is 1.699.
#
#         5. Make a decision.
#
#         Since the test statistic (8.66) is greater than the critical value (1.699), we reject the null
#               hypothesis and conclude that caffeine has a significant effect on reaction time at a 90% confidence level.
#
#         Interpretation of the results:
#
#        The results of the hypothesis test indicate that caffeine has a significant effect on reaction time at
#           a 90% confidence level. This means that we can be 90% confident that the true average reaction time
#           in the population is different from 0 seconds.
#
#            However, it is important to note that statistical significance does not necessarily mean practical significance.
#                   A statistically significant result may be too small to have any practical meaning.
#
#           To determine the practical significance of the result, we would need to consider the clinical significance
#             of the decrease in reaction time. For example, a decrease in reaction time of 0.05 seconds may not be clinically
#             significant for all activities.
#
#      Despite this, the results of this study suggest that caffeine can improve reaction time,
#            which could be beneficial for certain tasks, such as driving or playing sports.
